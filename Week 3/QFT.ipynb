# %%
from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister, transpile
from qiskit.visualization import array_to_latex
from qiskit_aer import AerSimulator
from qiskit.circuit.library import QFT
from numpy import sqrt
from qiskit.quantum_info import Statevector, Operator

# %%
circ = QFT(3).decompose()
display(circ.draw(output='mpl'))
circ.save_unitary()

# %%
simulator = AerSimulator(method = 'unitary')
circuit = transpile(circ, simulator)
results = simulator.run(circuit).result()
unitary = results.get_unitary(circuit)
array_to_latex(unitary*sqrt(8))
# Out:
# $$
#
# \begin{bmatrix}
# 1 & 1 & 1 & 1 & 1 & 1 & 1 & 1  \\
#  1 & \frac{\sqrt{2}}{2} + \frac{\sqrt{2} i}{2} & i & - \frac{\sqrt{2}}{2} + \frac{\sqrt{2} i}{2} & -1 & - \frac{\sqrt{2}}{2} - \frac{\sqrt{2} i}{2} & - i & \frac{\sqrt{2}}{2} - \frac{\sqrt{2} i}{2}  \\
#  1 & i & -1 & - i & 1 & i & -1 & - i  \\
#  1 & - \frac{\sqrt{2}}{2} + \frac{\sqrt{2} i}{2} & - i & \frac{\sqrt{2}}{2} + \frac{\sqrt{2} i}{2} & -1 & \frac{\sqrt{2}}{2} - \frac{\sqrt{2} i}{2} & i & - \frac{\sqrt{2}}{2} - \frac{\sqrt{2} i}{2}  \\
#  1 & -1 & 1 & -1 & 1 & -1 & 1 & -1  \\
#  1 & - \frac{\sqrt{2}}{2} - \frac{\sqrt{2} i}{2} & i & \frac{\sqrt{2}}{2} - \frac{\sqrt{2} i}{2} & -1 & \frac{\sqrt{2}}{2} + \frac{\sqrt{2} i}{2} & - i & - \frac{\sqrt{2}}{2} + \frac{\sqrt{2} i}{2}  \\
#  1 & - i & -1 & i & 1 & - i & -1 & i  \\
#  1 & \frac{\sqrt{2}}{2} - \frac{\sqrt{2} i}{2} & - i & - \frac{\sqrt{2}}{2} - \frac{\sqrt{2} i}{2} & -1 & - \frac{\sqrt{2}}{2} + \frac{\sqrt{2} i}{2} & i & \frac{\sqrt{2}}{2} + \frac{\sqrt{2} i}{2}  \\
#  \end{bmatrix}
# $$

# %%
zero = Statevector.from_label('0')
one = Statevector.from_label('1')
ket_101 = one.tensor(zero).tensor(one)
ket_101.draw(output='bloch')

# %%
# Out:
# ---------------------------------------------------------------------------
# QiskitError                               Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 ket_101.evolve(unitary).draw("latex")
#
# File c:\Users\felip\anaconda3\envs\coding_with_qiskit\Lib\site-packages\qiskit\quantum_info\states\statevector.py:402, in Statevector.evolve(self, other, qargs)
#     400 # check dimension
#     401 if self.dims(qargs) != other.input_dims():
# --> 402     raise QiskitError(
#     403         "Operator input dimensions are not equal to statevector subsystem dimensions."
#     404     )
#     405 return Statevector._evolve_operator(ret, other, qargs=qargs)
#
# QiskitError: 'Operator input dimensions are not equal to statevector subsystem dimensions.'

# %%
circ = QFT(4).decompose()
display(circ.draw(output='mpl'))
circ.save_unitary()

# %%
simulator = AerSimulator(method = 'unitary')
circuit = transpile(circ, simulator)
results = simulator.run(circuit).result()
unitary = results.get_unitary(circuit)
array_to_latex(unitary*sqrt(16))
# Out:
# $$
#
# \begin{bmatrix}
# 1 & 1 & 1 & 1 & \cdots & 1 & 1 & 1  \\
#  1 & 0.9238795325 + 0.3826834324 i & \frac{\sqrt{2}}{2} + \frac{\sqrt{2} i}{2} & 0.3826834324 + 0.9238795325 i & \cdots & 0.3826834324 - 0.9238795325 i & \frac{\sqrt{2}}{2} - \frac{\sqrt{2} i}{2} & 0.9238795325 - 0.3826834324 i  \\
#  1 & \frac{\sqrt{2}}{2} + \frac{\sqrt{2} i}{2} & i & - \frac{\sqrt{2}}{2} + \frac{\sqrt{2} i}{2} & \cdots & - \frac{\sqrt{2}}{2} - \frac{\sqrt{2} i}{2} & - i & \frac{\sqrt{2}}{2} - \frac{\sqrt{2} i}{2}  \\
#  1 & 0.3826834324 + 0.9238795325 i & - \frac{\sqrt{2}}{2} + \frac{\sqrt{2} i}{2} & -0.9238795325 - 0.3826834324 i & \cdots & -0.9238795325 + 0.3826834324 i & - \frac{\sqrt{2}}{2} - \frac{\sqrt{2} i}{2} & 0.3826834324 - 0.9238795325 i  \\
#  \vdots & \vdots & \vdots & \vdots & \ddots & \vdots & \vdots & \vdots \\
#  1 & 0.3826834324 - 0.9238795325 i & - \frac{\sqrt{2}}{2} - \frac{\sqrt{2} i}{2} & -0.9238795325 + 0.3826834324 i & \cdots & -0.9238795325 - 0.3826834324 i & - \frac{\sqrt{2}}{2} + \frac{\sqrt{2} i}{2} & 0.3826834324 + 0.9238795325 i  \\
#  1 & \frac{\sqrt{2}}{2} - \frac{\sqrt{2} i}{2} & - i & - \frac{\sqrt{2}}{2} - \frac{\sqrt{2} i}{2} & \cdots & - \frac{\sqrt{2}}{2} + \frac{\sqrt{2} i}{2} & i & \frac{\sqrt{2}}{2} + \frac{\sqrt{2} i}{2}  \\
#  1 & 0.9238795325 - 0.3826834324 i & \frac{\sqrt{2}}{2} - \frac{\sqrt{2} i}{2} & 0.3826834324 - 0.9238795325 i & \cdots & 0.3826834324 + 0.9238795325 i & \frac{\sqrt{2}}{2} + \frac{\sqrt{2} i}{2} & 0.9238795325 + 0.3826834324 i  \\
#  \end{bmatrix}
# $$
