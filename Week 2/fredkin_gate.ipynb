# %% [markdown]
# # Fredkin Gate Decomposition
#
# Implements the Fredkin (controlled-SWAP) gate and progressively decomposes it into smaller gates (Toffoli, then CSX/CX), verifying the unitary at each stage using `AerSimulator`.

# %%
from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister, transpile
from qiskit.visualization import array_to_latex
from qiskit_aer import AerSimulator

# %%
circ = QuantumCircuit(3)

circ.ccx(0,2,1)
circ.ccx(1,2,0)
circ.ccx(0,2,1)

display(circ.draw(output='mpl'))
circ.save_unitary()

# %%
simulator = AerSimulator(method = 'unitary')
circuit = transpile(circ, simulator)
results = simulator.run(circuit).result()
unitary = results.get_unitary(circuit)
array_to_latex(unitary)

# %%
circ = QuantumCircuit(3)

circ.cx(0,1)

circ.ccx(1,2,0)

circ.cx(0,1)

display(circ.draw(output='mpl'))
circ.save_unitary()

# %%
simulator = AerSimulator(method = 'unitary')
circuit = transpile(circ, simulator)
results = simulator.run(circuit).result()
unitary = results.get_unitary(circuit)
array_to_latex(unitary)

# %% [markdown]
# Now replace middle Toffoli with sqrtX gates and CX gates

# %%
circ = QuantumCircuit(3)

circ.cx(0,1)

circ.csx(1,0)
circ.cx(2,1)
circ.csx(1,0).inverse()
circ.cx(2,1)
circ.csx(2,0)

circ.cx(0,1)

display(circ.draw(output='mpl'))
circ.save_unitary()

# %%
simulator = AerSimulator(method = 'unitary')
circuit = transpile(circ, simulator)
results = simulator.run(circuit).result()
unitary = results.get_unitary(circuit)
array_to_latex(unitary)
